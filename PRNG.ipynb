# %% [markdown]
# <a href="https://colab.research.google.com/github/Nusrat-Richi/Advanced-Cryptography/blob/main/PRNG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Function to generate random numbers
def linearCongruentialMethod(Xo, m, a, c, randomNums,noOfRandomNums):

    # Initialize the seed state
    randomNums[0] = Xo

    # Traverse to generate required numbers of random numbers
    for i in range(1, noOfRandomNums):

        # Follow the linear congruential method
        randomNums[i] = ((randomNums[i - 1] * a) + c) % m

if __name__ == '__main__':

    # Seed value
    Xo = 10
    # Modulus parameter
    m = 7
    # Multiplier term
    a = 5
    # Increment term
    c = 3
    # Number of Random numbers
    noOfRandomNums = 20

    # To store random numbers
    randomNums = [0] * (noOfRandomNums)
    linearCongruentialMethod(Xo, m, a, c, randomNums, noOfRandomNums)

    # Print the generated random numbers
    for i in randomNums:
        print(i, end = " ")
# Out:
# 10 4 2 6 5 0 3 4 2 6 5 0 3 4 2 6 5 0 3 4
